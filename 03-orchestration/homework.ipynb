# %% [markdown]
# ## Question 1. Run Mage
# #### Answer:  Mage version -- 0.9.71

# %% [markdown]
# ## Question 2. Creating a project
# #### Answer: There are 55 lines in the metadata.yaml file

# %% [markdown]
# ## Question 3. Creating a pipeline
# #### Answer: 3,403,766
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 4. Data preparation
# #### Answer: 3,316,216
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 5. Train a model
# #### Answer: 24.77
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 6. Register the model
# #### Answer: 4,534
# ![image.png](attachment:image.png)
